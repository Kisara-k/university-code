# %%
import matplotlib.pyplot as plt

labels = [row[1:5] for row in data]

labels = list(map(list, zip(*labels)))

x_values = [row[0] for row in data]
for label_data in labels:
    plt.plot(x_values, label_data)

plt.xlabel('Array Length')
plt.ylabel('Average Time in ms')
plt.title('Sorting Algorithm Complexity - K S Kodithuwakku 220323N')
plt.legend(['Insertion', 'Bubble', 'Bubble Optimized', 'Selection'])

plt.show()

# %%
with open(r"C:\Users\ASUS\My-Git\university-code\semester-2\CS2023 - Data Structures and Algorithms\Times.txt", "r") as file:
    input = file.read()

rows = [line.split() for line in input.strip().split('\n')]
data = [[float(item) for item in row] for row in rows]
